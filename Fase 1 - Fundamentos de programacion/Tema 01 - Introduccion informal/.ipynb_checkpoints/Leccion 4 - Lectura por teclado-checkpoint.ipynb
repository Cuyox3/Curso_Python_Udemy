# %%
#la funcion input deja meter datos desde consola, todo es en cadenas
valor= input()
# Out:
# calor

# %%
valor =  input ("Introduce un numero entero:")
# Out:
# Introduce un numero entero:5

# %%
#convertir valor a otro

# %%
valor= int(valor)

# %%
valor= input("Introduce un valor entero: ")
# Out:
# Introduce un valor entero: 1.5

# %%
valor = float(valor) #se cambia ya que es flotante

# %%
valor +2
# Out:
# 3.5

# %%
#str(te da los datos en string)
