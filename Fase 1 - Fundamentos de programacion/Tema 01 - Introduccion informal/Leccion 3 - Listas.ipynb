# %%
numeros = [1,2,3,4,5]
# las listas tienen que estar separados por comas

# %%
datos=  [4,"una cadena", 5 , 9, "otra cadena", "aun otra cadena" ]

# %%
datos [5]
# Out:
# 'aun otra cadena'

# %%
datos[-2:]
# Out:
# ['otra cadena', 'aun otra cadena']

# %%
numeros + [5,6,7,8 ]
# Out:
# [1, 2, 3, 4, 5, 5, 6, 7, 8]

# %%
#aqui si se pueden reorganizar los datos

# %%
#append nos permite añadir datos

# %%
numeros.append("Buzz")

# %%
numeros
# Out:
# [1, 2, 3, 4, 5, 'Buzz']

# %%
numeros.append(7*2)

# %%
numeros
# Out:
# [1, 2, 3, 4, 5, 12, 14]

# %%
letras= ['a','b','c','d','e']

# %%
letras
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %%
letras [:3]
# Out:
# ['a', 'b', 'c']

# %%
letras[:3]= ['A','B','C']

# %%
letras
# Out:
# ['A', 'B', 'C', 'd', 'e']

# %%
letras [:3]
# Out:
# ['A', 'B', 'C']

# %%
letras [:3]=[]

# %%
#Se peuden borrar las listas si se le asigna el valor de una lista vacia

# %%
letras
# Out:
# ['d', 'e']

# %%
len (letras )
# Out:
# 2

# %%
# se pueden anidar listas

# %%
a =[1,2,3]

# %%
b= [4,5,6]

# %%
c= [7,8,9]

# %%
r =[a,b,c ]

# %%
r
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
#se puede asigar a varios datos de las listas ya anidadas

# %%
r[0][0]
# Out:
# 1

# %%
r[2][2]
# Out:
# 9
