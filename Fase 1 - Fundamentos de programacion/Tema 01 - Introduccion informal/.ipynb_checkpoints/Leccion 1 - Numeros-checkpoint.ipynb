# %%
3+2
# Out:
# 5

# %%
3-2
# Out:
# 1

# %%
3*2
# Out:
# 6

# %%
# Dibision 
3/2
# Out:
# 1.5

# %%
# un numero con punto es una division 
# el modulo te resta la parte decimal 
3%2
# Out:
# 1

# %%
#potencia con ** 
3**3
# Out:
# 27

# %%
3-2+4*10
# Out:
# 41

# %%
3/4*2
# Out:
# 1.5

# %%
3*4/2
# Out:
# 6.0

# %%
# asignacion de variables 
n=3

# %%
n*10
# Out:
# 30

# %%
n+n/n
# Out:
# 4.0

# %%
n=10
m=15

# %%
n
m
# Out:
# 15

# %%
n+m
# Out:
# 25

# %%
n=m

# %%
n
# Out:
# 15

# %%
# las variables no pueden comenzar por un numero 
# Las variables no pueden tener espacios
# Las variables no pueden tener simbolos 
# Los espacioas en las variables se escriben como __

# %%
nota1 =5 
nota2 = 10
nota3 = 15

# %%
nota1+nota2+nota3
# Out:
# 30

# %%
notaFinal = (nota1+nota2+nota3)/3

# %%
notaFinal
# Out:
# 10.0
